# %%
import os
import pickle as pkl
import sys
import numpy as np
import pandas as pd
import sklearn
import csv
from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import MDS
import seaborn as sns
import ot
import plotly.graph_objs as go
import plotly.express as px
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Define unique colors
unique_colours = np.array(["#d2b700", "#db8b08", "#c7512c", "#c13547", "#a03663", "#753a7a", "#4b488e", "#005692", "#006a8b", "#007b75", "#008a52", "#9aa400"])
colour_index = {colour: idx for idx, colour in enumerate(unique_colours)}
matrix_size = len(unique_colours)

### configuration
n_eps = 15 # number of epsilon values tried
eps_range = [0.04, 5] # the range of epsilon searched
epsilons = np.logspace(np.log10(eps_range[0]), np.log10(eps_range[1]), n_eps) # epsilon values

# %%
def add_colored_label(ax, x, y, bgcolor, width=1, height=1):
  rect = Rectangle((x, y), width, height, facecolor=bgcolor)
  ax.add_patch(rect)
  
def show_heatmaps(vmin_val, vmax_val, matrices, titles, cbar_label=None, color_labels=None):
    num_plots = len(matrices)
    fig, axs = plt.subplots(1, num_plots, figsize=(5*num_plots, 5))

    if num_plots == 1:
        axs = [axs]

    for i, (matrix, title) in enumerate(zip(matrices, titles)):
        ax = axs[i]
        
        im = ax.imshow(matrix, aspect='auto', vmin=vmin_val, vmax=vmax_val)
        ax.set_title(title)

        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        cbar = fig.colorbar(im, cax=cax)
        cbar.set_label(cbar_label)

        # Adjust the height of the color bar
        position = cax.get_position()
        new_position = [position.x0, position.y0 + 0.1, position.width, position.height * 0.8]
        cax.set_position(new_position)

        if color_labels is not None:
            ax.axis('off')
            for idx, color in enumerate(color_labels):
                add_colored_label(ax, -1.5, idx-0.5, color, width=0.8)
                add_colored_label(ax, idx-0.5, matrix.shape[1] - 0.2, color, height=0.8)

            ax.set_aspect('equal')
            ax.set_xlim(-3.0, matrix.shape[1])
            ax.set_ylim(-1, len(color_labels)+1.4)
            ax.invert_yaxis()

            for spine in ax.spines.values():
                spine.set_visible(False)

    plt.tight_layout()
    plt.show()


def transform_value(value):
    return -value + 3.5

def RSA(matrix1, matrix2, method='pearson'):
  upper_tri_1 = matrix1[np.triu_indices(matrix1.shape[0], k=1)]
  upper_tri_2 = matrix2[np.triu_indices(matrix2.shape[0], k=1)]
  if method == 'pearson':
    corr, _ = pearsonr(upper_tri_1, upper_tri_2)
  elif method == 'spearman':
    corr, _ = spearmanr(upper_tri_1, upper_tri_2)

  return corr

def comp_matching_rate(OT_plan, k, order="maximum"):
  # This function computes the matching rate, assuming that in the optimal transportation plan,
  # the items in the i-th row and the j-th column are the same (correct mactch) when i = j.
  # Thus, the diagonal elements of the optimal transportation plan represent the probabilities
  # that the same items (colors) match between the two structures.

  # Get the diagonal elements
  diagonal = np.diag(OT_plan)
  # Get the top k values for each row
  if order == "maximum":
      topk_values = np.partition(OT_plan, -k)[:, -k:]
  elif order == "minimum":
      topk_values = np.partition(OT_plan, k - 1)[:, :k]
  # Count the number of rows where the diagonal is in the top k values and compute the matching rate
  count = np.sum([diagonal[i] in topk_values[i] for i in range(OT_plan.shape[0])])
  matching_rate = count / OT_plan.shape[0] * 100
  return matching_rate

# Function to plot the embeddings
def plot_embeddings(embeddings, titles, color_labels, overlay=False):
    fig = go.Figure()
    
    if overlay:
        for i, embedding in enumerate(embeddings):
            fig.add_trace(go.Scatter3d(
                x=embedding[:, 0],
                y=embedding[:, 1],
                z=embedding[:, 2],
                mode='markers+text',
                marker=dict(size=10, color=color_labels),
                text=color_labels,
                textposition="top center",
                name=titles[i]
            ))
    else:
        for i, embedding in enumerate(embeddings):
            fig = go.Figure()
            fig.add_trace(go.Scatter3d(
                x=embedding[:, 0],
                y=embedding[:, 1],
                z=embedding[:, 2],
                mode='markers+text',
                marker=dict(size=10, color=color_labels),
                text=color_labels,
                textposition="top center"
            ))
            fig.update_layout(
                title=f'MDS Embedding - {titles[i]}',
                scene=dict(
                    xaxis_title='Dimension 1',
                    yaxis_title='Dimension 2',
                    zaxis_title='Dimension 3'
                ),
                height=800
            )
    fig.show()

# Define the function to compute GWD
def compute_min_gwd(matrix_1, matrix_2, epsilons):

    OT_plans = []
    gwds = []
    matching_rates = []

    for epsilon in epsilons:
      OT, gw_log = ot.gromov.entropic_gromov_wasserstein(C1=matrix_1, C2=matrix_2 , epsilon=epsilon, loss_fun="square_loss", log=True)  # optimization
      gwd = gw_log['gw_dist']
      matching_rate = comp_matching_rate(OT, k=1)  # calculate the top 1 matching rate
      OT_plans.append(OT)
      gwds.append(gwd)
      matching_rates.append(matching_rate)

    return min(gwds)

def GWD_and_plot(matrix1, matrix2, epsilons):
    
    OT_plans = []
    gwds = []
    matching_rates = []

    for epsilon in epsilons:
      OT, gw_log = ot.gromov.entropic_gromov_wasserstein(C1=matrix1, C2=matrix2 , epsilon=epsilon, loss_fun="square_loss", log=True)  # optimization
      gwd = gw_log['gw_dist']
      matching_rate = comp_matching_rate(OT, k=1)  # calculate the top 1 matching rate
      OT_plans.append(OT)
      gwds.append(gwd)
      matching_rates.append(matching_rate)

      
    plt.scatter(epsilons, gwds, c=matching_rates)
    plt.xlabel("epsilon")
    plt.ylabel("GWD")
    plt.xscale('log')
    plt.grid(True, which = 'both')
    cbar = plt.colorbar()
    cbar.set_label(label='Matching Rate (%)')
    plt.show()

    # extract the best epsilon that minimizes the GWD
    min_gwd = min(gwds)
    best_eps_idx = gwds.index(min_gwd)
    best_eps = epsilons[best_eps_idx]
    OT_plan = OT_plans[best_eps_idx]
    matching_rate = matching_rates[best_eps_idx]

    show_heatmaps(0, 0.1, matrices=[OT_plan], titles=[f'Optimal transportation plan \n GWD={min_gwd:.3f} \n matching rate : {matching_rate:.1f}%'])

    return OT_plan, gwds, matching_rates


def OT_epsilon(epsilons, OT_plans, gwds, e_ind, matching_rates):

    best_eps_idx = e_ind
    min_gwd = gwds[best_eps_idx]
    best_eps = epsilons[best_eps_idx]
    OT_plan = OT_plans[best_eps_idx]
    matching_rate = matching_rates[best_eps_idx]

    show_heatmaps(0, 0.05,
        matrices=[OT_plan],
        titles=[f'Optimal transportation plan \n GWD={min_gwd:.3f} \n matching rate : {matching_rate:.1f}%'],
        color_labels=unique_colours)
    
# Define the function to shuffle the matrix
def shuffle_upper_triangular_and_asymmetritisize(matrix, size):
    matrix_copy = matrix.copy()
    # Set the diagonal elements to zero
    np.fill_diagonal(matrix_copy, 0)

    # Shuffle the upper triangular elements
    upper_tri_indices = np.triu_indices(size, 1)
    upper_tri_values = matrix_copy[upper_tri_indices].copy()
    np.random.shuffle(upper_tri_values)
    matrix_copy[upper_tri_indices] = upper_tri_values
    
    # Set the lower triangular part of the matrix to the negative of the upper triangular part
    for i in range(size):
        for j in range(i + 1, size):
            matrix_copy[j, i] = -matrix_copy[i, j]
    
    return matrix_copy

# Shuffle elements across rows except the diagonal elements
def shuffle_column_and_asymmetritisize(matrix, size):
    matrix_copy = matrix.copy()
    np.fill_diagonal(matrix_copy, 0)

    # Set the lower triangular part of the matrix to the negative of the upper triangular part
    for i in range(size):
        for j in range(i + 1, size):
            matrix_copy[j, i] = -matrix_copy[i, j]

    for i in range(size):
        non_diag_indices = [j for j in range(matrix_size) if j != i]
        non_diag_values = matrix_copy[non_diag_indices, i].copy()
        np.random.shuffle(non_diag_values)
        matrix_copy[non_diag_indices, i] = non_diag_values
    
    return matrix_copy

# %%
# Create matrix
matrix_1 = np.zeros((matrix_size, matrix_size))
matrix_2 = np.zeros((matrix_size, matrix_size))

# Load the second CSV file
df_PM1 = pd.read_csv('617663_kana_colourPreferenceQualia_2024-06-25_14h38.37.490.csv')

# Extract columns
colour1_1 = df_PM1['colour1']
colour2_1 = df_PM1['colour2']
target_preference_1 = df_PM1['target_preference']

# Fill the matrix
for c1, c2, tp in zip(colour1_1, colour2_1, target_preference_1):
    I = colour_index[c1]
    j = colour_index[c2]
    matrix_1[I, j] = tp

# Load the second CSV file
df_PM2 = pd.read_csv('348000_kana_colourPreferenceQualia_2024-06-25_17h18.18.443.csv')

# Extract columns
colour1_2 = df_PM2['colour1']
colour2_2 = df_PM2['colour2']
target_preference_2 = df_PM2['target_preference']

# Fill the matrix
for c1, c2, tp in zip(colour1_2, colour2_2, target_preference_2):
    I = colour_index[c1]
    j = colour_index[c2]
    matrix_2[I, j] = tp

# %% [markdown]
# # No Value Mapping - asymmetric

# %%
matrix_1_copy = matrix_1.copy()

# Set the diagonal elements to zero
np.fill_diagonal(matrix_1_copy, np.nan)

no_value_mapping_1 = matrix_1_copy

# Set the lower triangular part of the matrix to NaN
lower_tri_indices = np.tril_indices(matrix_size, -1)
no_value_mapping_1[lower_tri_indices] = np.nan

# Convert to DataFrame for better readability
no_value_mapping_1_df = pd.DataFrame(no_value_mapping_1, index=unique_colours, columns=unique_colours)

# %%
matrix_2_copy = matrix_2.copy()

# Set the diagonal elements to NaN
np.fill_diagonal(matrix_2_copy, np.nan)

no_value_mapping_2 = matrix_2_copy

# Set the lower triangular part of the matrix to NaN
lower_tri_indices = np.tril_indices(matrix_size, -1)
no_value_mapping_2[lower_tri_indices] = np.nan

# Convert to DataFrame for better readability
no_value_mapping_2_df = pd.DataFrame(no_value_mapping_2, index=unique_colours, columns=unique_colours)

# %%
show_heatmaps(0, 7, matrices=[no_value_mapping_1, no_value_mapping_2], titles=['Subject 1', 'Subject 2'], cbar_label="preference", color_labels=unique_colours)

# %% [markdown]
# # No Value Mapping - symmetric

# %%
# Calculate the transpose of the matrix
matrix_1_transpose = matrix_1.T

# Sum the original matrix and its transpose
matrix_sum_1 = matrix_1 + matrix_1_transpose

# Set the diagonal elements to zero
np.fill_diagonal(matrix_sum_1, 0)

no_value_mapping_1_sym = matrix_sum_1

# Convert to DataFrame for better readability
no_value_mapping_1_sym_df = pd.DataFrame(no_value_mapping_1_sym, index=unique_colours, columns=unique_colours)

# %%
# Calculate the transpose of the matrix
matrix_2_transpose = matrix_2.T

# Sum the original matrix and its transpose
matrix_sum_2 = matrix_2 + matrix_2_transpose

# Set the diagonal elements to zero
np.fill_diagonal(matrix_sum_2, 0)

no_value_mapping_2_sym = matrix_sum_2

# Convert to DataFrame for better readability
matrix_transformed_2_sym_df = pd.DataFrame(no_value_mapping_2_sym, index=unique_colours, columns=unique_colours)

# %%
show_heatmaps( 0, 7, matrices=[no_value_mapping_1_sym, no_value_mapping_2_sym], titles=['Subject 1', 'Subject 2'], cbar_label="preference", color_labels=unique_colours)

# %% [markdown]
# # Value Mapping to -3.5 ~ 3.5 - raw matrix

# %%
# Apply the transformation rule to the entire matrix
value_mapped_raw_1 = np.vectorize(transform_value)(matrix_1)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_raw_1, np.nan)

# Set the lower triangular part of the matrix to NaN
lower_tri_indices = np.tril_indices(matrix_size, -1)
value_mapped_raw_1[lower_tri_indices] = np.nan

# Convert to DataFrame for better readability
value_mapped_raw_1_df = pd.DataFrame(value_mapped_raw_1, index=unique_colours, columns=unique_colours)

# %%
# Apply the transformation rule to the entire matrix
value_mapped_raw_2 = np.vectorize(transform_value)(matrix_2)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_raw_2, np.nan)

# Set the lower triangular part of the matrix to NaN
lower_tri_indices = np.tril_indices(matrix_size, -1)
value_mapped_raw_2[lower_tri_indices] = np.nan

# Convert to DataFrame for better readability
value_mapped_raw_2_df = pd.DataFrame(value_mapped_raw_2, index=unique_colours, columns=unique_colours)

# %%
show_heatmaps(-3.5, 3.5, matrices=[value_mapped_raw_1, value_mapped_raw_2], titles=['Subject 1', 'Subject 2'], cbar_label="preference", color_labels=unique_colours)

# %% [markdown]
# # Value Mapping to -3.5 ~ 3.5 - assymetric matrix/opposite

# %%
# Apply the transformation rule to the entire matrix
value_mapped_as_1 = np.vectorize(transform_value)(matrix_1)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_as_1, 0)

# Set the lower triangular part of the matrix to the negative of the upper triangular part
for i in range(matrix_size):
    for j in range(i+1, matrix_size):
        value_mapped_as_1[j, i] = -value_mapped_as_1[i, j]

# Convert to DataFrame for better readability
value_mapped_as_1_df = pd.DataFrame(value_mapped_as_1, index=unique_colours, columns=unique_colours)

# %%
# Apply the transformation rule to the entire matrix
value_mapped_as_2 = np.vectorize(transform_value)(matrix_2)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_as_2, 0)

# Set the lower triangular part of the matrix to the negative of the upper triangular part
for i in range(matrix_size):
    for j in range(i+1, matrix_size):
        value_mapped_as_2[j, i] = -value_mapped_as_2[i, j]

# Convert to DataFrame for better readability
value_mapped_as_2_df = pd.DataFrame(value_mapped_as_2, index=unique_colours, columns=unique_colours)

# %%
show_heatmaps(-3.5, 3.5, matrices=[value_mapped_as_1, value_mapped_as_2], titles=['Subject 1', 'Subject 2'], cbar_label="preference", color_labels=unique_colours)

# %% [markdown]
# # Value Mapping to -3.5 - 3.5 - symmetrical

# %%
# Calculate the transpose of the matrix
matrix_1_transpose = matrix_1.T

# Sum the original matrix and its transpose
matrix_sum_1 = matrix_1 + matrix_1_transpose

# Apply the transformation rule to the entire matrix
value_mapped_sym_1 = np.vectorize(transform_value)(matrix_sum_1)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_sym_1, 0)

# Convert to DataFrame for better readability
value_mapped_sym_1_df = pd.DataFrame(value_mapped_sym_1, index=unique_colours, columns=unique_colours)

# %%
# Calculate the transpose of the matrix
matrix_2_transpose = matrix_2.T

# Sum the original matrix and its transpose
matrix_sum_2 = matrix_2 + matrix_2_transpose

# Apply the transformation rule to the entire matrix
value_mapped_sym_2 = np.vectorize(transform_value)(matrix_sum_2)

# Set the diagonal elements to zero
np.fill_diagonal(value_mapped_sym_2, 0)

# Convert to DataFrame for better readability
value_mapped_sym_2_df = pd.DataFrame(value_mapped_sym_2, index=unique_colours, columns=unique_colours)

# %%
show_heatmaps(-3.5, 3.5, matrices=[value_mapped_sym_1, value_mapped_sym_2], titles=['Subject 1', 'Subject 2'], cbar_label="preference", color_labels=unique_colours)

# %% [markdown]
# # MDS

# %% [markdown]
# ### 1D DMS and overall preference rating

# %%
def plot_1DMDS_overallPreference(matrix_transformed_1, matrix_transformed_2, matrix_transformed_1_as, matrix_transformed_2_as, unique_colours):
    embeddings = []
    for RDM in [matrix_transformed_1, matrix_transformed_2]:
        mds = MDS(n_components=1, dissimilarity='precomputed', random_state=5)
        embedding = mds.fit_transform(RDM)
        embeddings.append(embedding)

    row_averages_1 = matrix_transformed_1_as.mean(axis=0).reshape(-1, 1)
    embeddings_1 = np.hstack((embeddings[0], row_averages_1))

    row_averages_2 = matrix_transformed_2_as.mean(axis=0).reshape(-1, 1)
    embeddings_2 = np.hstack((embeddings[1], row_averages_2))

    embeddings_3 = [embeddings_1, embeddings_2]

    # Plot the embeddings
    plt.figure(figsize=(12, 6))

    # Plot the first embedding
    plt.subplot(1, 2, 1)
    plt.scatter(embeddings_3[0][:, 0], embeddings_3[0][:, 1], color=unique_colours)
    for i, color in enumerate(unique_colours):
        plt.text(embeddings_3[0][i, 0], embeddings_3[0][i, 1], color, fontsize=12, color=color)
    plt.title('MDS Embedding - Subject 1')
    plt.xlabel('MDS Dimension 1', fontsize=14)
    plt.ylabel('Overall Preference value', fontsize=14)

    # Plot the second embedding
    plt.subplot(1, 2, 2)
    plt.scatter(embeddings_3[1][:, 0], embeddings_3[1][:, 1], color=unique_colours)
    for i, color in enumerate(unique_colours):
        plt.text(embeddings_3[1][i, 0], embeddings_3[1][i, 1], color, fontsize=12, color=color)
    plt.title('MDS Embedding - Subject 2')
    plt.xlabel('MDS Dimension 1', fontsize=14)
    plt.ylabel('Overall Preference value', fontsize=14)

    plt.tight_layout()
    plt.show()

# %%
plot_1DMDS_overallPreference(value_mapped_sym_1, value_mapped_sym_2, value_mapped_as_1, value_mapped_as_2, unique_colours)

# %% [markdown]
# ### 3D MDS

# %%
def plot_3D_embeddings(embeddings, titles, color_labels, overlay=False):

    if overlay:
        fig = go.Figure()
        for i, embedding in enumerate(embeddings):
            fig.add_trace(go.Scatter3d(
                x=embedding[:, 0],
                y=embedding[:, 1],
                z=embedding[:, 2],
                mode='markers+text',
                marker=dict(size=10, color=color_labels),
                text=color_labels,
                textposition="top center",
                name=titles[i]
            ))
        fig.update_layout(
            title='Overlayed MDS Embeddings',
            scene=dict(
                xaxis_title='Dimension 1',
                yaxis_title='Dimension 2',
                zaxis_title='Dimension 3'
            ),
            height=800,
            plot_bgcolor='white'
        )
        fig.show()
    else:
        for i, embedding in enumerate(embeddings):
            fig = go.Figure()
            fig.add_trace(go.Scatter3d(
                x=embedding[:, 0],
                y=embedding[:, 1],
                z=embedding[:, 2],
                mode='markers+text',
                marker=dict(size=10, color=color_labels),
                text=color_labels,
                textposition="top center"
            ))
            fig.update_layout(
                title=f'MDS Embedding - {titles[i]}',
                scene=dict(
                    xaxis_title='Dimension 1',
                    yaxis_title='Dimension 2',
                    zaxis_title='Dimension 3'
                ),
                height=800,
                plot_bgcolor='white'
            )
            fig.show()


def plot_3DMDS(matrix_transformed_1, matrix_transformed_2, titles, color_labels, overlay=False):
    # Compute MDS for each transformed matrix
    embeddings = []
    for RDM in [matrix_transformed_1, matrix_transformed_2]:
        mds = MDS(n_components=3, dissimilarity='precomputed', random_state=5)
        embedding = mds.fit_transform(RDM)
        embeddings.append(embedding)

    plot_3D_embeddings(embeddings, titles, color_labels, overlay=False)

# %%
# Plot the embeddings
plot_3DMDS(value_mapped_sym_1, value_mapped_sym_2, titles=['Subject 1', 'Subject 2'], color_labels=unique_colours, overlay=False)

# %% [markdown]
# ### 2D MDS

# %%
def plot_2DMDS(matrix_transformed_1, matrix_transformed_2):
    # List to store the embeddings
    embeddings = []

    # Compute MDS for each transformed matrix
    for RDM in [matrix_transformed_1, matrix_transformed_2]:
        mds = MDS(n_components=2, dissimilarity='precomputed', random_state=5)
        embedding = mds.fit_transform(RDM)
        embeddings.append(embedding)

    # Define unique colors
    unique_colours = np.array(["#d2b700", "#db8b08", "#c7512c", "#c13547", "#a03663", "#753a7a", "#4b488e", "#005692", "#006a8b", "#007b75", "#008a52", "#9aa400"])

    # Plot the embeddings
    plt.figure(figsize=(12, 6))

    # Plot the first embedding
    plt.subplot(1, 2, 1)
    plt.scatter(embeddings[0][:, 0], embeddings[0][:, 1], color=unique_colours)
    for i, color in enumerate(unique_colours):
        plt.text(embeddings[0][i, 0], embeddings[0][i, 1], color, fontsize=12, color=color)
    plt.title('MDS Embedding - Subject 1')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    # Plot the second embedding
    plt.subplot(1, 2, 2)
    plt.scatter(embeddings[1][:, 0], embeddings[1][:, 1], color=unique_colours)
    for i, color in enumerate(unique_colours):
        plt.text(embeddings[1][i, 0], embeddings[1][i, 1], color, fontsize=12, color=color)
    plt.title('MDS Embedding - Subject 2')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    plt.tight_layout()
    plt.show()

# %%
plot_2DMDS(value_mapped_sym_1, value_mapped_sym_2)

# %% [markdown]
# ### 3D MDS with preference as the z-axis

# %%
def plot_3DMDS_overallPreference(matrix_transformed_1, matrix_transformed_2, matrix_transformed_1_as, matrix_transformed_2_as, unique_colours):
    # List to store the embeddings
    embeddings = []

    # First matrix
    mds = MDS(n_components=2, dissimilarity='precomputed', random_state=5)
    embedding_2d = mds.fit_transform(matrix_transformed_1)

    # Calculate the average value for each column
    row_averages_1 = matrix_transformed_1_as.mean(axis=0).reshape(-1, 1)

    # Add the row averages as the third dimension
    embedding_3d = np.hstack((embedding_2d, row_averages_1))
    embeddings.append(embedding_3d)

    # Second matrix
    mds = MDS(n_components=2, dissimilarity='precomputed', random_state=5)
    embedding_2d = mds.fit_transform(matrix_transformed_2)

    # Calculate the average value for each row
    row_averages_2 = matrix_transformed_2_as.mean(axis=0).reshape(-1, 1)

    # Add the row averages as the third dimension
    embedding_3d = np.hstack((embedding_2d, row_averages_2))
    embeddings.append(embedding_3d)

    plot_3D_embeddings(embeddings, titles=['Subject 1', 'Subject 2'], color_labels=unique_colours, overlay=False)

# %%
plot_3DMDS_overallPreference(value_mapped_sym_1, value_mapped_sym_2, value_mapped_as_1, value_mapped_as_2, unique_colours)

# %% [markdown]
# # GWOT

# %% [markdown]
# ### GWOT with symmetric matrix (preference distance)

# %%
RSA_corr = RSA(value_mapped_sym_1, value_mapped_sym_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_sym, gwds_sym, matching_rates_sym = GWD_and_plot(value_mapped_sym_1, value_mapped_sym_2, epsilons)
# Out:
# RSA correlation coefficient :  0.42451626289800193
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/ot/bregman/_sinkhorn.py:531: UserWarning:
#
# Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.

# %%
embeddings = []
for RDM in [value_mapped_sym_1, value_mapped_sym_2]:
    mds = MDS(n_components=3, dissimilarity='precomputed', random_state=5)
    embedding = mds.fit_transform(RDM)
    embeddings.append(embedding)

embeddings_y = embeddings[1]
# barycentric projection of embedding2 to the space of embedding1
projected_embeddings_x = OT_plan_sym @ embeddings_y * len(OT_plan_sym)

plot_3D_embeddings(
    embeddings=[embeddings_y, projected_embeddings_x],
    titles=['Subject 1', 'Subject 2'],
    overlay=False,
    color_labels=unique_colours)

# %% [markdown]
# ### GWOT with asymmetric matrix (preference ratings)

# %%
RSA_corr = RSA(value_mapped_as_1, value_mapped_as_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_as, gwds_as, matching_rates_as = GWD_and_plot(value_mapped_as_1, value_mapped_as_2, epsilons)
# Out:
# RSA correlation coefficient :  0.42451626289800193
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/ot/bregman/_sinkhorn.py:531: UserWarning:
#
# Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.

# %% [markdown]
# ### GWOT with random matrix - triangular based

# %% [markdown]
# #### Kana

# %%
value_mapped_as_shuffledByDiagonal_1 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_1, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_1, value_mapped_as_shuffledByDiagonal_1)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_withShuffledDiagonal_1, gwds_withShuffledDiagonal_1, matching_rates_withShuffledDiagonal_1 = GWD_and_plot(value_mapped_as_1, value_mapped_as_shuffledByDiagonal_1, epsilons)
# Out:
# RSA correlation coefficient :  -0.09575970382809817
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/ot/bregman/_sinkhorn.py:531: UserWarning:
#
# Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.

# %% [markdown]
# #### Angus

# %%
value_mapped_as_shuffledByDiagonal_2 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_2, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_1, value_mapped_as_shuffledByDiagonal_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_withShuffledDiagonal_2, gwds_withShuffledDiagonal_2, matching_rates_withShuffledDiagonal_2 = GWD_and_plot(value_mapped_as_2, value_mapped_as_shuffledByDiagonal_2, epsilons)
# Out:
# RSA correlation coefficient :  0.28585215553171467

# %% [markdown]
# ### GWOT with random matrix - column based

# %% [markdown]
# #### Kana

# %%
value_mapped_as_shuffledByColumn_1 = shuffle_column_and_asymmetritisize(value_mapped_raw_1, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_1, value_mapped_as_shuffledByColumn_1)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_withShuffledColumn_1, gwds_withShuffledColumn_1, matching_rates_withShuffledColumn_1 = GWD_and_plot(value_mapped_as_1, value_mapped_as_shuffledByColumn_1, epsilons)
# Out:
# RSA correlation coefficient :  0.4353196627711416

# %% [markdown]
# #### Angus

# %%
value_mapped_as_shuffledByColumn_2 = shuffle_column_and_asymmetritisize(value_mapped_raw_2, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_2, value_mapped_as_shuffledByColumn_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_withShuffledColumn_2, gwds_withShuffledColumn_2, matching_rates_withShuffledColumn_2 = GWD_and_plot(value_mapped_as_2, value_mapped_as_shuffledByColumn_2, epsilons)
# Out:
# RSA correlation coefficient :  0.4825356703561487

# %% [markdown]
# ### GWOT with random matrix - shuffled and shuffled (diagonal based)

# %% [markdown]
# #### Kana

# %%
value_mapped_as_shuffledByDiagonal_1_1 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_1, matrix_size)
value_mapped_as_shuffledByDiagonal_1_2 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_1, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_shuffledByDiagonal_1_1, value_mapped_as_shuffledByDiagonal_1_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_ShuffledwithShuffledDiagonal_1, gwds_ShuffledwithShuffledDiagonal_1, matching_rates_ShuffledwithShuffledDiagonal_1 = GWD_and_plot(value_mapped_as_shuffledByDiagonal_1_1, value_mapped_as_shuffledByDiagonal_1_2, epsilons)
# Out:
# RSA correlation coefficient :  0.21155681080874783

# %% [markdown]
# #### Angus

# %%
value_mapped_as_shuffledByDiagonal_2_1 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_2, matrix_size)
value_mapped_as_shuffledByDiagonal_2_2 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_2, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_shuffledByDiagonal_2_1, value_mapped_as_shuffledByDiagonal_2_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_ShuffledwithShuffledDiagonal_2, gwds_ShuffledwithShuffledDiagonal_2, matching_rates_ShuffledwithShuffledDiagonal_2 = GWD_and_plot(value_mapped_as_shuffledByDiagonal_2_1, value_mapped_as_shuffledByDiagonal_2_2, epsilons)
# Out:
# RSA correlation coefficient :  -0.07798338368580067

# %% [markdown]
# ### GWOT with random matrix - shuffled and shuffled (column based)

# %% [markdown]
# #### Kana

# %%
value_mapped_as_shuffledByColumn_1_1 = shuffle_column_and_asymmetritisize(value_mapped_raw_1, matrix_size)
value_mapped_as_shuffledByColumn_1_2 = shuffle_column_and_asymmetritisize(value_mapped_raw_1, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_shuffledByColumn_1_1, value_mapped_as_shuffledByColumn_1_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_ShuffledwithShuffledColumn_1, gwds_ShuffledwithShuffledColumn_1, matching_rates_ShuffledwithShuffledColumn_1 = GWD_and_plot(value_mapped_as_shuffledByDiagonal_1_1, value_mapped_as_shuffledByDiagonal_1_2, epsilons)
# Out:
# RSA correlation coefficient :  0.4225292806923304

# %% [markdown]
# #### Angus

# %%
value_mapped_as_shuffledByColumn_2_1 = shuffle_column_and_asymmetritisize(value_mapped_raw_2, matrix_size)
value_mapped_as_shuffledByColumn_2_2 = shuffle_column_and_asymmetritisize(value_mapped_raw_2, matrix_size)

# %%
RSA_corr = RSA(value_mapped_as_shuffledByColumn_2_1, value_mapped_as_shuffledByColumn_2_2)
print('RSA correlation coefficient : ', RSA_corr)
OT_plan_ShuffledwithShuffledColumn_2, gwds_ShuffledwithShuffledColumn_2, matching_rates_ShuffledwithShuffledColumn_2 = GWD_and_plot(value_mapped_as_shuffledByColumn_2_1, value_mapped_as_shuffledByColumn_2_2, epsilons)
# Out:
# RSA correlation coefficient :  0.5364974113344467

# %% [markdown]
# ### Distribution of the shuffle to shuffle GWD (diagonal)

# %% [markdown]
# #### Kana

# %%
### configuration
n_eps = 6 # number of epsilon values tried
eps_range = [0.04, 5] # the range of epsilon searched
epsilons = np.logspace(np.log10(eps_range[0]), np.log10(eps_range[1]), n_eps) # epsilon values

# %%
# Run the process 1000 times
min_gwds = []
for _ in range(100):
    # First shuffling
    value_mapped_raw_shuffledByDiagonal_1_1 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_1, matrix_size)
    # Second shuffling
    value_mapped_raw_shuffledByDiagonal_1_2 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_1, matrix_size)
        
    RSA_corr = RSA(value_mapped_raw_shuffledByDiagonal_1_1, value_mapped_raw_shuffledByDiagonal_1_2)
    print('RSA correlation coefficient : ', RSA_corr)

    # Compute the minimum GWD
    min_gwd = compute_min_gwd(value_mapped_raw_shuffledByDiagonal_1_1, value_mapped_raw_shuffledByDiagonal_1_2, epsilons)
    min_gwds.append(min_gwd)

# Calculate average and standard deviation
avg_min_gwd = np.mean(min_gwds)
std_min_gwd = np.std(min_gwds)

# Plot the distribution of the minimum GWD values
plt.hist(min_gwds, bins=30, alpha=0.75)
plt.title('Distribution of Minimum GWD Values')
plt.xlabel('Minimum GWD')
plt.ylabel('Frequency')
plt.show()

# Print the average and standard deviation
print(f'Average Minimum GWD: {avg_min_gwd}')
print(f'Standard Deviation of Minimum GWD: {std_min_gwd}')
# Out:
# RSA correlation coefficient :  -0.1688103507499713
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/ot/bregman/_sinkhorn.py:531: UserWarning:
#
# Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
# RSA correlation coefficient :  -0.14865844815083398
# RSA correlation coefficient :  -0.2569749246211977
# RSA correlation coefficient :  -0.15117743597572617
# RSA correlation coefficient :  0.12591122476241368
# RSA correlation coefficient :  0.1259112247624137
# RSA correlation coefficient :  0.1385061638868746
# RSA correlation coefficient :  0.12843021258730586
# RSA correlation coefficient :  0.1914049082096103
# RSA correlation coefficient :  -0.2065951681233542
# RSA correlation coefficient :  -0.11843059425212779
# RSA correlation coefficient :  -0.20407618029846195
# RSA correlation coefficient :  -0.06301286210449986
# RSA correlation coefficient :  -0.1612533872752949
# RSA correlation coefficient :  0.055379565665432604
# RSA correlation coefficient :  -0.00507614213197973
# RSA correlation coefficient :  -0.13102553337658873
# RSA correlation coefficient :  -0.03278500820579371
# RSA correlation coefficient :  -0.10079767947788257
# RSA correlation coefficient :  0.01255677264226554
# RSA correlation coefficient :  -0.07308881340406856
# RSA correlation coefficient :  0.0453036143658639
# RSA correlation coefficient :  0.00499980916758903
# RSA correlation coefficient :  -0.03782298385557805
# RSA correlation coefficient :  0.025151711766726467
# RSA correlation coefficient :  0.042784626540971746
# RSA correlation coefficient :  0.0982023586885997
# RSA correlation coefficient :  -0.09324071600320595
# RSA correlation coefficient :  0.14606312736155114
# RSA correlation coefficient :  0.16369604213579642
# RSA correlation coefficient :  -0.1108736307774513
# RSA correlation coefficient :  -0.005076142131979675
# RSA correlation coefficient :  -0.0705698255791764
# RSA correlation coefficient :  -0.21163314377313838
# RSA correlation coefficient :  -0.01011411778176405
# RSA correlation coefficient :  -0.20155719247356976
# RSA correlation coefficient :  0.004999809167589047
# RSA correlation coefficient :  -0.09827869165299034
# RSA correlation coefficient :  -0.06301286210449983
# RSA correlation coefficient :  -0.07560780122896076
# RSA correlation coefficient :  -0.002557154307087482
# RSA correlation coefficient :  0.32239227510400376
# RSA correlation coefficient :  -0.2645318880958743
# RSA correlation coefficient :  -0.21163314377313844
# RSA correlation coefficient :  -0.040341971680470205
# RSA correlation coefficient :  -0.17384832639975578
# RSA correlation coefficient :  -0.15621541162551053
# RSA correlation coefficient :  0.15613907866111987
# RSA correlation coefficient :  0.20903782298385562
# RSA correlation coefficient :  -0.07308881340406857
# RSA correlation coefficient :  0.05034159001564828
# RSA correlation coefficient :  0.037746650891187374
# RSA correlation coefficient :  -0.16377237510018705
# RSA correlation coefficient :  -0.1864432655242167
# RSA correlation coefficient :  0.027670699591618636
# RSA correlation coefficient :  0.10072134651349186
# RSA correlation coefficient :  -0.07812678905385291
# RSA correlation coefficient :  0.29972138467997406
# RSA correlation coefficient :  0.08560741956413878
# RSA correlation coefficient :  0.186366932559826
# RSA correlation coefficient :  0.21155681080874777
# RSA correlation coefficient :  0.08056944391435444
# RSA correlation coefficient :  -0.11591160642723562
# RSA correlation coefficient :  0.24934162818213046
# RSA correlation coefficient :  0.10827830998816841
# RSA correlation coefficient :  0.08812640738903098
# RSA correlation coefficient :  -0.002557154307087539
# RSA correlation coefficient :  -0.0579748864547155
# RSA correlation coefficient :  0.04278462654097173
# RSA correlation coefficient :  -0.01767108125644059
# RSA correlation coefficient :  -0.03278500820579367
# RSA correlation coefficient :  -0.09324071600320599
# RSA correlation coefficient :  0.14858211518644326
# RSA correlation coefficient :  0.11079729781306061
# RSA correlation coefficient :  -0.14865844815083396
# RSA correlation coefficient :  0.02011373611694211
# RSA correlation coefficient :  0.13850616388687464
# RSA correlation coefficient :  0.020113736116942085
# RSA correlation coefficient :  -0.05545589862982331
# RSA correlation coefficient :  -0.14865844815083398
# RSA correlation coefficient :  -0.176367314224648
# RSA correlation coefficient :  0.004999809167589027
# RSA correlation coefficient :  -0.17384832639975578
# RSA correlation coefficient :  -0.06805083775428426
# RSA correlation coefficient :  0.06545551696500136
# RSA correlation coefficient :  0.2392656768825618
# RSA correlation coefficient :  0.03018968741651083
# RSA correlation coefficient :  0.1737719934353651
# RSA correlation coefficient :  0.0503415900156483
# RSA correlation coefficient :  -0.07056982557917639
# RSA correlation coefficient :  0.04782260219075607
# RSA correlation coefficient :  0.015075760467157775
# RSA correlation coefficient :  -0.09072172817831387
# RSA correlation coefficient :  -0.0302660203809015
# RSA correlation coefficient :  -0.3451394984924241
# RSA correlation coefficient :  -0.06553184992939205
# RSA correlation coefficient :  0.08812640738903092
# RSA correlation coefficient :  0.13598717606198238
# RSA correlation coefficient :  0.05537956566543265
# RSA correlation coefficient :  -0.06553184992939201
# Average Minimum GWD: 5.368321689873676
# Standard Deviation of Minimum GWD: 1.7293613206762704

# %% [markdown]
# #### Angus

# %%
# Run the process 1000 times
min_gwds = []
for _ in range(100):
    # First shuffling
    value_mapped_raw_shuffledByDiagonal_2_1 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_2, matrix_size)
    # Second shuffling
    value_mapped_raw_shuffledByDiagonal_2_2 = shuffle_upper_triangular_and_asymmetritisize(value_mapped_raw_2, matrix_size)

    RSA_corr = RSA(value_mapped_raw_shuffledByDiagonal_2_1, value_mapped_raw_shuffledByDiagonal_2_2)
    print('RSA correlation coefficient : ', RSA_corr) 
    
    # Compute the minimum GWD
    min_gwd = compute_min_gwd(value_mapped_raw_shuffledByDiagonal_2_1, value_mapped_raw_shuffledByDiagonal_2_2, epsilons)
    min_gwds.append(min_gwd)

# Calculate average and standard deviation
avg_min_gwd = np.mean(min_gwds)
std_min_gwd = np.std(min_gwds)

# Plot the distribution of the minimum GWD values
plt.hist(min_gwds, bins=30, alpha=0.75)
plt.title('Distribution of Minimum GWD Values')
plt.xlabel('Minimum GWD')
plt.ylabel('Frequency')
plt.show()

# Print the average and standard deviation
print(f'Average Minimum GWD: {avg_min_gwd}')
print(f'Standard Deviation of Minimum GWD: {std_min_gwd}')
# Out:
# RSA correlation coefficient :  -0.05305891238670702
# RSA correlation coefficient :  -0.12783232628398802
# RSA correlation coefficient :  -0.053058912386706965
# RSA correlation coefficient :  0.04040785498489429
# RSA correlation coefficient :  0.04040785498489429
# RSA correlation coefficient :  0.09648791540785512
# RSA correlation coefficient :  -0.10913897280966782
# RSA correlation coefficient :  -0.009441087613293033
# RSA correlation coefficient :  -0.059290030211480424
# RSA correlation coefficient :  -0.07175226586102718
# RSA correlation coefficient :  0.10271903323262856
# RSA correlation coefficient :  -0.14652567975830832
# RSA correlation coefficient :  0.30834592145015155
# RSA correlation coefficient :  0.021714501510574073
# RSA correlation coefficient :  0.12141238670694875
# RSA correlation coefficient :  -0.12160120845921459
# RSA correlation coefficient :  0.14010574018126906
# RSA correlation coefficient :  -0.01567220543806648
# RSA correlation coefficient :  0.02794561933534747
# RSA correlation coefficient :  -0.14029456193353484
# RSA correlation coefficient :  -0.06552114803625382
# RSA correlation coefficient :  0.16503021148036273
# RSA correlation coefficient :  -0.07175226586102727
# RSA correlation coefficient :  0.15256797583081586
# RSA correlation coefficient :  0.10895015105740194
# RSA correlation coefficient :  0.12764350453172216
# RSA correlation coefficient :  0.015483383685800664
# RSA correlation coefficient :  -0.171450151057402
# RSA correlation coefficient :  -0.003209969788519636
# RSA correlation coefficient :  -0.015672205438066484
# RSA correlation coefficient :  -0.11537009063444126
# RSA correlation coefficient :  0.046638972809667674
# RSA correlation coefficient :  0.20864803625377676
# RSA correlation coefficient :  0.0902567975830817
# RSA correlation coefficient :  -0.015672205438066446
# RSA correlation coefficient :  -0.0156722054380665
# RSA correlation coefficient :  -0.14652567975830835
# RSA correlation coefficient :  0.003021148036253789
# RSA correlation coefficient :  0.10271903323262853
# RSA correlation coefficient :  0.052870090634441154
# RSA correlation coefficient :  0.027945619335347435
# RSA correlation coefficient :  0.18995468277945646
# RSA correlation coefficient :  0.2771903323262843
# RSA correlation coefficient :  0.1463368580060425
# RSA correlation coefficient :  0.04663897280966771
# RSA correlation coefficient :  0.052870090634441154
# RSA correlation coefficient :  0.09025679758308167
# RSA correlation coefficient :  -0.053058912386706944
# RSA correlation coefficient :  -0.10913897280966779
# RSA correlation coefficient :  -0.06552114803625386
# RSA correlation coefficient :  0.2834214501510577
# RSA correlation coefficient :  -0.12783232628398797
# RSA correlation coefficient :  -0.12160120845921463
# RSA correlation coefficient :  0.08402567975830823
# RSA correlation coefficient :  -0.059290030211480424
# RSA correlation coefficient :  -0.19014350453172224
# RSA correlation coefficient :  0.009252265861027209
# RSA correlation coefficient :  -0.05305891238670701
# RSA correlation coefficient :  0.20864803625377681
# RSA correlation coefficient :  0.06533232628398798
# RSA correlation coefficient :  0.009252265861027224
# RSA correlation coefficient :  0.12764350453172219
# RSA correlation coefficient :  -0.2150679758308159
# RSA correlation coefficient :  -0.1527567975830817
# RSA correlation coefficient :  0.02794561933534749
# RSA correlation coefficient :  -0.10913897280966778
# RSA correlation coefficient :  0.015483383685800621
# RSA correlation coefficient :  0.015483383685800644
# RSA correlation coefficient :  -0.1029078549848944
# RSA correlation coefficient :  0.046638972809667695
# RSA correlation coefficient :  0.07156344410876143
# RSA correlation coefficient :  0.10271903323262856
# RSA correlation coefficient :  -0.040596676737160185
# RSA correlation coefficient :  -0.046827794561933575
# RSA correlation coefficient :  -0.23999244712990955
# RSA correlation coefficient :  -0.14652567975830832
# RSA correlation coefficient :  -0.1340634441087615
# RSA correlation coefficient :  -0.04682779456193356
# RSA correlation coefficient :  -0.15898791540785506
# RSA correlation coefficient :  0.16503021148036282
# RSA correlation coefficient :  -0.028134441087613312
# RSA correlation coefficient :  -0.046827794561933575
# RSA correlation coefficient :  0.1712613293051361
# RSA correlation coefficient :  0.1214123867069488
# RSA correlation coefficient :  0.03417673716012091
# RSA correlation coefficient :  0.12141238670694873
# RSA correlation coefficient :  -0.2026057401812691
# RSA correlation coefficient :  -0.04059667673716018
# RSA correlation coefficient :  0.24603474320241728
# RSA correlation coefficient :  -0.028134441087613305
# RSA correlation coefficient :  0.0715634441087614
# RSA correlation coefficient :  -0.21506797583081594
# RSA correlation coefficient :  0.15256797583081588
# RSA correlation coefficient :  0.10895015105740191
# RSA correlation coefficient :  0.09025679758308164
# RSA correlation coefficient :  -0.12160120845921459
# RSA correlation coefficient :  -0.02190332326283986
# RSA correlation coefficient :  -0.0655211480362538
# RSA correlation coefficient :  0.052870090634441126
# RSA correlation coefficient :  0.052870090634441154
# Average Minimum GWD: 2.1573667128507172
# Standard Deviation of Minimum GWD: 0.6206476921260771

# %% [markdown]
# ### Distribution of the shuffle to shuffle GWD (column)

# %% [markdown]
# #### Kana

# %%
# Run the process 1000 times
min_gwds = []
for _ in range(100):
    # First shuffling
    value_mapped_as_shuffledByColumn_1_1 = shuffle_column_and_asymmetritisize(value_mapped_raw_1, matrix_size)
    # Second shuffling
    value_mapped_as_shuffledByColumn_1_2 = shuffle_column_and_asymmetritisize(value_mapped_raw_1, matrix_size)

    RSA_corr = RSA(value_mapped_as_shuffledByColumn_1_1, value_mapped_as_shuffledByColumn_1_2)
    print('RSA correlation coefficient : ', RSA_corr)
    
    # Compute the minimum GWD
    min_gwd = compute_min_gwd(value_mapped_as_shuffledByColumn_1_2, value_mapped_as_shuffledByColumn_1_2, epsilons)
    min_gwds.append(min_gwd)

# Calculate average and standard deviation
avg_min_gwd = np.mean(min_gwds)
std_min_gwd = np.std(min_gwds)

# Plot the distribution of the minimum GWD values
plt.hist(min_gwds, bins=30, alpha=0.75)
plt.title('Distribution of Minimum GWD Values')
plt.xlabel('Minimum GWD')
plt.ylabel('Frequency')
plt.show()

# Print the average and standard deviation
print(f'Average Minimum GWD: {avg_min_gwd}')
print(f'Standard Deviation of Minimum GWD: {std_min_gwd}')
# Out:
# RSA correlation coefficient :  0.2971857559339964
# RSA correlation coefficient :  0.3017633983495968
# RSA correlation coefficient :  0.3586223093815671
# RSA correlation coefficient :  0.31122726493322583
# RSA correlation coefficient :  0.3018308633876696
# RSA correlation coefficient :  0.3243433261150154
# RSA correlation coefficient :  0.4245681701863082
# RSA correlation coefficient :  0.20725741741498668
# RSA correlation coefficient :  0.26235064952273224
# RSA correlation coefficient :  0.459047304790052
# RSA correlation coefficient :  0.3650444064666568
# RSA correlation coefficient :  0.43543848769764676
# RSA correlation coefficient :  0.4145212539081144
# RSA correlation coefficient :  0.34152302388854916
# RSA correlation coefficient :  0.3446309074822547
# RSA correlation coefficient :  0.35081854474584045
# RSA correlation coefficient :  0.2821262057002733
# RSA correlation coefficient :  0.18676482732686048
# RSA correlation coefficient :  0.380195142923146
# RSA correlation coefficient :  0.48247964182798897
# RSA correlation coefficient :  0.296688706825918
# RSA correlation coefficient :  0.4081119235123319
# RSA correlation coefficient :  0.2694952064654425
# RSA correlation coefficient :  0.4105085752864419
# RSA correlation coefficient :  0.2637786255757148
# RSA correlation coefficient :  0.30461636457181346
# RSA correlation coefficient :  0.42222718234304185
# RSA correlation coefficient :  0.3113739382727044
# RSA correlation coefficient :  0.411434731971013
# RSA correlation coefficient :  0.2562738905856315
# RSA correlation coefficient :  0.44407953340151385
# RSA correlation coefficient :  0.3752841377704041
# RSA correlation coefficient :  0.3287851190186057
# RSA correlation coefficient :  0.5449942800366981
# RSA correlation coefficient :  0.27677080953215494
# RSA correlation coefficient :  0.28636715020285225
# RSA correlation coefficient :  0.2908611168718963
# RSA correlation coefficient :  0.5099237098204182
# RSA correlation coefficient :  0.41746900971093887
# RSA correlation coefficient :  0.11293649106548938
# RSA correlation coefficient :  0.3757241618904565
# RSA correlation coefficient :  0.3939472363177519
# RSA correlation coefficient :  0.3717773996295935
# RSA correlation coefficient :  0.5126436899717064
# RSA correlation coefficient :  0.3650337408098676
# RSA correlation coefficient :  0.33444003793875976
# RSA correlation coefficient :  0.22163769299553235
# RSA correlation coefficient :  0.3293745388474758
# RSA correlation coefficient :  0.18787108536633315
# RSA correlation coefficient :  0.25208673504612883
# RSA correlation coefficient :  0.47043703994529723
# RSA correlation coefficient :  0.17265144811276925
# RSA correlation coefficient :  0.3453397543342391
# RSA correlation coefficient :  0.18985739242786726
# RSA correlation coefficient :  0.5256458388588424
# RSA correlation coefficient :  0.4184607810921662
# RSA correlation coefficient :  0.2355757765377431
# RSA correlation coefficient :  0.4992954625055415
# RSA correlation coefficient :  0.3816003599546641
# RSA correlation coefficient :  0.3022436654614048
# RSA correlation coefficient :  0.4475824087716769
# RSA correlation coefficient :  0.37445886675426543
# RSA correlation coefficient :  0.37256471602222285
# RSA correlation coefficient :  0.20362384726263777
# RSA correlation coefficient :  0.26723491357832213
# RSA correlation coefficient :  0.39095215005365813
# RSA correlation coefficient :  0.4642705390203086
# RSA correlation coefficient :  0.4104063656462674
# RSA correlation coefficient :  0.413275499969318
# RSA correlation coefficient :  0.6066903451517993
# RSA correlation coefficient :  0.4268854871948377
# RSA correlation coefficient :  0.3843032843751238
# RSA correlation coefficient :  0.4750889181398096
# RSA correlation coefficient :  0.5100283472036771
# RSA correlation coefficient :  0.31563919017005054
# RSA correlation coefficient :  0.26358806396737083
# RSA correlation coefficient :  0.4742197321524989
# RSA correlation coefficient :  0.20534900510965362
# RSA correlation coefficient :  0.36815033665389535
# RSA correlation coefficient :  0.4800652046532365
# RSA correlation coefficient :  0.484343545695979
# RSA correlation coefficient :  0.5190943031093916
# RSA correlation coefficient :  0.10079871911778847
# RSA correlation coefficient :  0.48664766489438727
# RSA correlation coefficient :  0.41211433767223365
# RSA correlation coefficient :  0.42799777711755405
# RSA correlation coefficient :  0.3723488777666353
# RSA correlation coefficient :  0.3068533452074399
# RSA correlation coefficient :  0.22937973041355914
# RSA correlation coefficient :  0.3237640997356779
# RSA correlation coefficient :  0.36520641086040456
# RSA correlation coefficient :  0.36599005775713095
# RSA correlation coefficient :  0.5188755361807436
# RSA correlation coefficient :  0.3756768684016744
# RSA correlation coefficient :  0.4286148708049003
# RSA correlation coefficient :  0.2916776270187766
# RSA correlation coefficient :  0.366184549570113
# RSA correlation coefficient :  0.45115008271000107
# RSA correlation coefficient :  0.20950829063938034
# RSA correlation coefficient :  0.4101480955395519
# Average Minimum GWD: 1.2667992613716009e-15
# Standard Deviation of Minimum GWD: 3.5487904628540293e-16

# %% [markdown]
# #### Angus

# %%
# Run the process 1000 times
min_gwds = []
for _ in range(100):
    # First shuffling
    value_mapped_as_shuffledByColumn_2_1 = shuffle_column_and_asymmetritisize(value_mapped_raw_2, matrix_size)
    # Second shuffling
    value_mapped_as_shuffledByColumn_2_2 = shuffle_column_and_asymmetritisize(value_mapped_raw_2, matrix_size)
    
    RSA_corr = RSA(value_mapped_as_shuffledByColumn_2_1, value_mapped_as_shuffledByColumn_2_2)
    print('RSA correlation coefficient : ', RSA_corr)

    # Compute the minimum GWD
    min_gwd = compute_min_gwd(value_mapped_as_shuffledByColumn_2_2, value_mapped_as_shuffledByColumn_2_2, epsilons)
    min_gwds.append(min_gwd)

# Calculate average and standard deviation
avg_min_gwd = np.mean(min_gwds)
std_min_gwd = np.std(min_gwds)

# Plot the distribution of the minimum GWD values
plt.hist(min_gwds, bins=30, alpha=0.75)
plt.title('Distribution of Minimum GWD Values')
plt.xlabel('Minimum GWD')
plt.ylabel('Frequency')
plt.show()

# Print the average and standard deviation
print(f'Average Minimum GWD: {avg_min_gwd}')
print(f'Standard Deviation of Minimum GWD: {std_min_gwd}')
# Out:
# RSA correlation coefficient :  0.47307178034902
# RSA correlation coefficient :  0.5992626007239736
# RSA correlation coefficient :  0.6087403589696112
# RSA correlation coefficient :  0.4803132189690052
# RSA correlation coefficient :  0.5214935346309645
# RSA correlation coefficient :  0.5903720207035238
# RSA correlation coefficient :  0.43364033776825617
# RSA correlation coefficient :  0.599443613734886
# RSA correlation coefficient :  0.6299688974743983
# RSA correlation coefficient :  0.36093130725006994
# RSA correlation coefficient :  0.5550562229633532
# RSA correlation coefficient :  0.4448257738853949
# RSA correlation coefficient :  0.5643262749076119
# RSA correlation coefficient :  0.4940220694969746
# RSA correlation coefficient :  0.49723446604031135
# RSA correlation coefficient :  0.49918220908779426
# RSA correlation coefficient :  0.40042195973256844
# RSA correlation coefficient :  0.31392343766083397
# RSA correlation coefficient :  0.3705585366043089
# RSA correlation coefficient :  0.5199935696142353
# RSA correlation coefficient :  0.547241161303845
# RSA correlation coefficient :  0.5650915103792468
# RSA correlation coefficient :  0.4380889058256853
# RSA correlation coefficient :  0.5147495431234395
# RSA correlation coefficient :  0.5143227939549728
# RSA correlation coefficient :  0.49139244272237326
# RSA correlation coefficient :  0.4142250104388988
# RSA correlation coefficient :  0.3809816253441393
# RSA correlation coefficient :  0.47543041177065565
# RSA correlation coefficient :  0.36356857210031157
# RSA correlation coefficient :  0.4086213300759541
# RSA correlation coefficient :  0.6047791774832565
# RSA correlation coefficient :  0.4933319430780552
# RSA correlation coefficient :  0.45918209180501135
# RSA correlation coefficient :  0.5666714714661576
# RSA correlation coefficient :  0.5160681242614464
# RSA correlation coefficient :  0.42517439005650337
# RSA correlation coefficient :  0.33669445632090955
# RSA correlation coefficient :  0.5067292339283692
# RSA correlation coefficient :  0.45044050307202127
# RSA correlation coefficient :  0.4944830976071885
# RSA correlation coefficient :  0.6312632609134974
# RSA correlation coefficient :  0.4786906296340748
# RSA correlation coefficient :  0.4308305725942591
# RSA correlation coefficient :  0.5161818774867546
# RSA correlation coefficient :  0.4211468004109846
# RSA correlation coefficient :  0.5034010880174077
# RSA correlation coefficient :  0.3828909380032642
# RSA correlation coefficient :  0.4176352205395712
# RSA correlation coefficient :  0.5490534527681828
# RSA correlation coefficient :  0.6024393569664276
# RSA correlation coefficient :  0.5829044792056541
# RSA correlation coefficient :  0.4830492774969268
# RSA correlation coefficient :  0.6309961825094351
# RSA correlation coefficient :  0.5609408782919927
# RSA correlation coefficient :  0.41900736066489364
# RSA correlation coefficient :  0.4776182924845726
# RSA correlation coefficient :  0.5511787244377562
# RSA correlation coefficient :  0.48969179712777
# RSA correlation coefficient :  0.4336373926998496
# RSA correlation coefficient :  0.4339301408221423
# RSA correlation coefficient :  0.46583807648445513
# RSA correlation coefficient :  0.3480431782934077
# RSA correlation coefficient :  0.4151989810795865
# RSA correlation coefficient :  0.5683758974094404
# RSA correlation coefficient :  0.4196365451550494
# RSA correlation coefficient :  0.43301797405873926
# RSA correlation coefficient :  0.5159921501941993
# RSA correlation coefficient :  0.451276858909304
# RSA correlation coefficient :  0.3300939375373504
# RSA correlation coefficient :  0.5132529843728328
# RSA correlation coefficient :  0.5360261366651734
# RSA correlation coefficient :  0.5007052881135423
# RSA correlation coefficient :  0.4026409163840722
# RSA correlation coefficient :  0.66627027780548
# RSA correlation coefficient :  0.3637003934862808
# RSA correlation coefficient :  0.41006924283168683
# RSA correlation coefficient :  0.5828528742188501
# RSA correlation coefficient :  0.36514254416794933
# RSA correlation coefficient :  0.4954298782386346
# RSA correlation coefficient :  0.5508586882268777
# RSA correlation coefficient :  0.35718192014672084
# RSA correlation coefficient :  0.5305727778621181
# RSA correlation coefficient :  0.4768782374939594
# RSA correlation coefficient :  0.4624598336532655
# RSA correlation coefficient :  0.5964096769877777
# RSA correlation coefficient :  0.44909052125638843
# RSA correlation coefficient :  0.3401599681622991
# RSA correlation coefficient :  0.4802785736813433
# RSA correlation coefficient :  0.2992615732496295
# RSA correlation coefficient :  0.4707076413305355
# RSA correlation coefficient :  0.5461971670971647
# RSA correlation coefficient :  0.3578608799775635
# RSA correlation coefficient :  0.5686671122184865
# RSA correlation coefficient :  0.4653712203611385
# RSA correlation coefficient :  0.5331793676744199
# RSA correlation coefficient :  0.37823595203440497
# RSA correlation coefficient :  0.538441682988237
# RSA correlation coefficient :  0.5991902296532683
# RSA correlation coefficient :  0.5809301327632449
# Average Minimum GWD: -7.698992304059826e-18
# Standard Deviation of Minimum GWD: 1.3834364286199422e-16
